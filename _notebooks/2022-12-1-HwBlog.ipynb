// %% [markdown]
// # Units 1-5
// - toc: true
// - badges: true
// - comments: true
// - categories: [jupyter]
// - title: Units 1-5

// %% [markdown]
// # Total - 4.75/5

// %% [markdown]
// ### Unit 1 - 0.95/1
// ![image.png](attachment:image.png)

// %% [markdown]
// ### Unit 2 - 1/1
//
// ![image.png](attachment:image.png)

// %% [markdown]
// ### Unit 3 - 0.9/1
//
// ![image.png](attachment:image.png)

// %% [markdown]
// ### Unit 4 - 1/1
//
// ![image.png](attachment:image.png)

// %% [markdown]
// ### Unit 5 - 0.9/1
//
// ![image.png](attachment:image.png)
